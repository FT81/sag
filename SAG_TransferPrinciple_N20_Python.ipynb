# %%
import numpy as np
from numpy import random
import pandas as pd
import math
import statistics as stats
import scipy.stats 
from scipy.stats import skew

# %%
dataframe = pd.DataFrame(columns=['TNumber','Transfer','TSum','SAG','SAGtf','SAGd',
                                     'GR','GRtf','GRd','GL','GLtf','GLd','Gini','Ginitf','Ginid',
                                     'Skew','mean','median',
                                     'percent1','percent2','percent3','percent4','percent5',
                                     'percent6','percent7','percent8','percent9','percent10',
                                     'percent11','percent12','percent13','percent14','percent15',
                                     'percent16','percent17','percent18','percent19','percent20',
                                     'percent1tf','percent2tf','percent3tf','percent4tf','percent5tf',
                                     'percent6tf','percent7tf','percent8tf','percent9tf','percent10tf',
                                     'percent11tf','percent12tf','percent13tf','percent14tf','percent15tf',
                                     'percent16tf','percent17tf','percent18tf','percent19tf','percent20tf',
                                     'value1','value2','value3','value4','value5',
                                     'value6','value7','value8','value9','value10',
                                     'value11','value12','value13','value14','value15',
                                     'value16','value17','value18','value19','value20',
                                     'value1tf','value2tf','value3tf','value4tf','value5tf',
                                     'value6tf','value7tf','value8tf','value9tf','value10tf',
                                     'value11tf','value12tf','value13tf','value14tf','value15tf',
                                     'value16tf','value17tf','value18tf','value19tf','value20tf'  
                                  ])

# %%
i=0
while i <=10000:
    
    lb=1
    ub=300
    
    val1=np.random.randint(lb,ub);val2=np.random.randint(lb,ub)
    val3=np.random.randint(lb,ub);val4=np.random.randint(lb,ub)
    val5=np.random.randint(lb,ub);val6=np.random.randint(lb,ub)
    val7=np.random.randint(lb,ub);val8=np.random.randint(lb,ub)
    val9=np.random.randint(lb,ub);val10=np.random.randint(lb,ub)
    val11=np.random.randint(lb,ub);val12=np.random.randint(lb,ub)
    val13=np.random.randint(lb,ub);val14=np.random.randint(lb,ub)
    val15=np.random.randint(lb,ub);val16=np.random.randint(lb,ub)
    val17=np.random.randint(lb,ub);val18=np.random.randint(lb,ub)
    val19=np.random.randint(lb,ub);val20=np.random.randint(lb,ub)
  
    vlist =[val1,val2,val3,val4,val5,val6,val7,val8,val9,val10,
            val1,val12,val13,val14,val15,val16,val17,val18,val19,val20]
    vlist.sort()
    
    value1=vlist[0];value2=vlist[1];value3=vlist[2];value4=vlist[3];value5=vlist[4]
    value6=vlist[5];value7=vlist[6];value8=vlist[7];value9=vlist[8];value10=vlist[9]
    value11=vlist[10];value12=vlist[11];value13=vlist[12];value14=vlist[13]
    value15=vlist[14];value16=vlist[15];value17=vlist[16];value18=vlist[17]
    value19=vlist[18];value20=vlist[19]
    
    summ=np.sum(vlist)
    mean=np.mean(vlist)
    median=np.median(vlist)
    n=20
    
    #weights for GL(2n-2i)/n
    lweight1=(2*n-2)/n;lweight2=(2*n-4)/n;lweight3=(2*n-6)/n;lweight4=(2*n-8)/n
    lweight5=(2*n-10)/n;lweight6=(2*n-12)/n;lweight7=(2*n-14)/n;lweight8=(2*n-16)/n
    lweight9=(2*n-18)/n;lweight10=(2*n-20)/n;lweight11=(2*n-22)/n;lweight12=(2*n-24)/n
    lweight13=(2*n-26)/n;lweight14=(2*n-28)/n;lweight15=(2*n-30)/n;lweight16=(2*n-32)/n
    lweight17=(2*n-34)/n;lweight18=(2*n-36)/n;lweight19=(2*n-38)/n
    
    #weights for GR(2i/n)
    rweight1=2/20;rweight2=4/20;rweight3=6/20;rweight4=8/20;rweight5=10/20;rweight6=12/20
    rweight7=14/20;rweight8=16/20;rweight9=18/20;rweight10=20/20;rweight11=22/20
    rweight12=24/20;rweight13=26/20;rweight14=28/20;rweight15=30/20;rweight16=32/20
    rweight17=34/20;rweight18=36/20;rweight19=38/20
    ############################################################################################
    value1tf=vlist[0];value2tf=vlist[1];value3tf=vlist[2];value4tf=vlist[3];value5tf=vlist[4]
    value6tf=vlist[5];value7tf=vlist[6];value8tf=vlist[7];value9tf=vlist[8];value10tf=vlist[9]
    value11tf=vlist[10];value12tf=vlist[11];value13tf=vlist[12];value14tf=vlist[13]
    value15tf=vlist[14];value16tf=vlist[15];value17tf=vlist[16];value18tf=vlist[17]
    value19tf=vlist[18];value20tf=vlist[19]

    TNumber=np.random.randint(1,190)#(n*(n-1))/2 = 190 possible progressive transfers
    TSum=random.choice([0.1,0.2,0.3,0.4,0.45,0.49])
    
    if(TNumber==1):
        value1tf=value1+TSum;value2tf=value2-TSum;Transfer='1<-2'
    elif(TNumber==2):
        value1tf=value1+TSum;value3tf=value3-TSum;Transfer='1<-3' 
    elif(TNumber==3):
        value1tf=value1+TSum;value4tf=value4-TSum;Transfer='1<-4' 
    elif(TNumber==4):
        value1tf=value1+TSum;value5tf=value5-TSum;Transfer='1<-5'
    elif(TNumber==5):
        value1tf=value1+TSum;value6tf=value6-TSum;Transfer='1<-6'
    elif(TNumber==6):
        value1tf=value1+TSum;value7tf=value7-TSum;Transfer='1<-7'
    elif(TNumber==7):
        value1tf=value1+TSum;value8tf=value8-TSum;Transfer='1<-8' 
    elif(TNumber==8):
        value1tf=value1+TSum;value9tf=value9-TSum;Transfer='1<-9' 
    elif(TNumber==9):
        value1tf=value1+TSum;value10tf=value10-TSum;Transfer='1<-10' 
    elif(TNumber==10):
        value1tf=value1+TSum;value11tf=value11-TSum;Transfer='1<-11' 
    elif(TNumber==11):
        value1tf=value1+TSum;value12tf=value12-TSum;Transfer='1<-12' 
    elif(TNumber==12):
        value1tf=value1+TSum;value13tf=value13-TSum;Transfer='1<-13'  
    elif(TNumber==13):
        value1tf=value1+TSum;value14tf=value14-TSum;Transfer='1<-14' 
    elif(TNumber==14):
        value1tf=value1+TSum;value15tf=value15-TSum;Transfer='1<-15' 
    elif(TNumber==15):
        value1tf=value1+TSum;value16tf=value16-TSum;Transfer='1<-16'   
    elif(TNumber==16):
        value1tf=value1+TSum;value17tf=value17-TSum;Transfer='1<-17'
    elif(TNumber==17):
        value1tf=value1+TSum;value18tf=value18-TSum;Transfer='1<-18' 
    elif(TNumber==18):
        value1tf=value1+TSum;value19tf=value19-TSum;Transfer='1<-19' 
    elif(TNumber==19):
        value1tf=value1+TSum;value20tf=value20-TSum;Transfer='1<-20' 
       
    elif(TNumber==20):
        value2tf=value2+TSum;value3tf=value3-TSum;Transfer='2<-3'  
    elif(TNumber==21):
        value2tf=value2+TSum;value4tf=value4-TSum;Transfer='2<-4'  
    elif(TNumber==22):
        value2tf=value2+TSum;value5tf=value5-TSum;Transfer='2<-5'
    elif(TNumber==23):
        value2tf=value2+TSum;value6tf=value6-TSum;Transfer='2<-6'   
    elif(TNumber==24):
        value2tf=value2+TSum;value7tf=value7-TSum;Transfer='2<-7'
    elif(TNumber==25):
        value2tf=value2+TSum;value8tf=value8-TSum;Transfer='2<-8'
    elif(TNumber==26):
        value2tf=value2+TSum;value9tf=value9-TSum;Transfer='2<-9'
    elif(TNumber==27):
        value2tf=value2+TSum;value10tf=value10-TSum;Transfer='2<-10'
    elif(TNumber==28):
        value2tf=value2+TSum;value11tf=value11-TSum;Transfer='2<-11'
    elif(TNumber==29):
        value2tf=value2+TSum;value12tf=value12-TSum;Transfer='2<-12'  
    elif(TNumber==30):
        value2tf=value2+TSum;value13tf=value13-TSum;Transfer='2<-13'   
    elif(TNumber==31):
        value2tf=value2+TSum;value14tf=value14-TSum;Transfer='2<-14' 
    elif(TNumber==32):
        value2tf=value2+TSum;value15tf=value15-TSum;Transfer='2<-15'
    elif(TNumber==33):
        value2tf=value2+TSum;value16tf=value16-TSum;Transfer='2<-16' 
    elif(TNumber==34):
        value2tf=value2+TSum;value17tf=value17-TSum;Transfer='2<-17'  
    elif(TNumber==35):
        value2tf=value2+TSum;value18tf=value18-TSum;Transfer='2<-18' 
    elif(TNumber==36):
        value2tf=value2+TSum;value19tf=value19-TSum;Transfer='2<-19' 
    elif(TNumber==37):
        value2tf=value2+TSum;value20tf=value20-TSum;Transfer='2<-20' 
  
    elif(TNumber==38):
        value3tf=value3+TSum;value4tf=value4-TSum;Transfer='3<-4'   
    elif(TNumber==39):
        value3tf=value3+TSum;value5tf=value5-TSum;Transfer='3<-5'
    elif(TNumber==40):
        value3tf=value3+TSum;value6tf=value6-TSum;Transfer='3<-6'  
    elif(TNumber==41):
        value3tf=value3+TSum;value7tf=value7-TSum;Transfer='3<-7'
    elif(TNumber==42):
        value3tf=value3+TSum;value8tf=value8-TSum;Transfer='3<-8'
    elif(TNumber==43):
        value3tf=value3+TSum;value9tf=value9-TSum;Transfer='3<-9'
    elif(TNumber==44):
        value3tf=value3+TSum;value10tf=value10-TSum;Transfer='3<-10'
    elif(TNumber==45):
        value3tf=value3+TSum;value11tf=value11-TSum;Transfer='3<-11'
    elif(TNumber==46):
        value3tf=value3+TSum;value12tf=value12-TSum;Transfer='3<-12' 
    elif(TNumber==47):
        value3tf=value3+TSum;value13tf=value13-TSum;Transfer='3<-13'   
    elif(TNumber==48):
        value3tf=value3+TSum;value14tf=value14-TSum;Transfer='3<-14' 
    elif(TNumber==49):
        value3tf=value3+TSum;value15tf=value15-TSum;Transfer='3<-15'
    elif(TNumber==50):
        value3tf=value3+TSum;value16tf=value16-TSum;Transfer='3<-16'
    elif(TNumber==51):
        value3tf=value3+TSum;value17tf=value17-TSum;Transfer='3<-17' 
    elif(TNumber==52):
        value3tf=value3+TSum;value18tf=value18-TSum;Transfer='3<-18' 
    elif(TNumber==53):
        value3tf=value3+TSum;value19tf=value19-TSum;Transfer='3<-19' 
    elif(TNumber==54):
        value3tf=value3+TSum;value20tf=value20-TSum;Transfer='3<-20'   
      
    elif(TNumber==55):
        value4tf=value4+TSum;value5tf=value5-TSum;Transfer='4<-5'
    elif(TNumber==56):
        value4tf=value4+TSum;value6tf=value6-TSum;Transfer='4<-6'  
    elif(TNumber==57):
        value4tf=value4+TSum;value7tf=value7-TSum;Transfer='4<-7'
    elif(TNumber==58):
        value4tf=value4+TSum;value8tf=value8-TSum;Transfer='4<-8'
    elif(TNumber==59):
        value4tf=value4+TSum;value9tf=value9-TSum;Transfer='4<-9'
    elif(TNumber==60):
        value4tf=value4+TSum;value10tf=value10-TSum;Transfer='4<-10'
    elif(TNumber==61):
        value4tf=value4+TSum;value11tf=value11-TSum;Transfer='4<-11'
    elif(TNumber==62):
        value4tf=value4+TSum;value12tf=value12-TSum;Transfer='4<-12' 
    elif(TNumber==63):
        value4tf=value4+TSum;value13tf=value13-TSum;Transfer='4<-13'
    elif(TNumber==64):
        value4tf=value4+TSum;value14tf=value14-TSum;Transfer='4<-14' 
    elif(TNumber==65):
        value4tf=value4+TSum;value15tf=value15-TSum;Transfer='4<-15'
    elif(TNumber==66):
        value4tf=value4+TSum;value16tf=value16-TSum;Transfer='4<-16'  
    elif(TNumber==67):
        value4tf=value4+TSum;value17tf=value17-TSum;Transfer='4<-17'  
    elif(TNumber==68):
        value4tf=value4+TSum;value18tf=value18-TSum;Transfer='4<-18' 
    elif(TNumber==69):
        value4tf=value4+TSum;value19tf=value19-TSum;Transfer='4<-19'  
    elif(TNumber==70):
        value4tf=value4+TSum;value20tf=value20-TSum;Transfer='4<-20' 
   
    elif(TNumber==71):
        value5tf=value5+TSum;value6tf=value6-TSum;Transfer='5<-6'
    elif(TNumber==72):
        value5tf=value5+TSum;value7tf=value7-TSum;Transfer='5<-7'
    elif(TNumber==73):
        value5tf=value5+TSum;value8tf=value8-TSum;Transfer='5<-8'
    elif(TNumber==74):
        value5tf=value5+TSum;value9tf=value9-TSum;Transfer='5<-9'
    elif(TNumber==75):
        value5tf=value5+TSum;value10tf=value10-TSum;Transfer='5<-10'
    elif(TNumber==76):
        value5tf=value5+TSum;value11tf=value11-TSum;Transfer='5<-11'
    elif(TNumber==77):
        value5tf=value5+TSum;value12tf=value12-TSum;Transfer='5<-12' 
    elif(TNumber==78):
        value5tf=value5+TSum;value13tf=value13-TSum;Transfer='5<-13'
    elif(TNumber==79):
        value5tf=value5+TSum;value14tf=value14-TSum;Transfer='5<-14' 
    elif(TNumber==80):
        value5tf=value5+TSum;value15tf=value15-TSum;Transfer='5<-15'
    elif(TNumber==81):
        value5tf=value5+TSum;value16tf=value16-TSum;Transfer='5<-16' 
    elif(TNumber==82):
        value5tf=value5+TSum;value17tf=value17-TSum;Transfer='5<-17'
    elif(TNumber==83):
        value5tf=value5+TSum;value18tf=value18-TSum;Transfer='5<-18' 
    elif(TNumber==84):
        value5tf=value5+TSum;value19tf=value19-TSum;Transfer='5<-19'  
    elif(TNumber==85):
        value5tf=value5+TSum;value20tf=value20-TSum;Transfer='5<-20' 
    
    elif(TNumber==86):
        value6tf=value6+TSum;value7tf=value7-TSum;Transfer='6<-7'
    elif(TNumber==87):
        value6tf=value6+TSum;value8tf=value8-TSum;Transfer='6<-8'
    elif(TNumber==88):
        value6tf=value6+TSum;value9tf=value9-TSum;Transfer='6<-9'
    elif(TNumber==89):
        value6tf=value6+TSum;value10tf=value10-TSum;Transfer='6<-10'
    elif(TNumber==90):
        value6tf=value6+TSum;value11tf=value11-TSum;Transfer='6<-11'
    elif(TNumber==91):
        value6tf=value6+TSum;value12tf=value12-TSum;Transfer='6<-12' 
    elif(TNumber==92):
        value6tf=value6+TSum;value13tf=value13-TSum;Transfer='6<-13'  
    elif(TNumber==93):
        value6tf=value6+TSum;value14tf=value14-TSum;Transfer='6<-14'   
    elif(TNumber==94):
        value6tf=value6+TSum;value15tf=value15-TSum;Transfer='6<-15'
    elif(TNumber==95):
        value6tf=value6+TSum;value16tf=value16-TSum;Transfer='6<-16'   
    elif(TNumber==96):
        value6tf=value6+TSum;value17tf=value17-TSum;Transfer='6<-17'
    elif(TNumber==97):
        value6tf=value6+TSum;value18tf=value18-TSum;Transfer='6<-18'
    elif(TNumber==98):
        value6tf=value6+TSum;value19tf=value19-TSum;Transfer='6<-19'
    elif(TNumber==99):
        value6tf=value6+TSum;value20tf=value20-TSum;Transfer='6<-20'
    
    elif(TNumber==100):
        value7tf=value7+TSum;value8tf=value8-TSum;Transfer='7<-8' 
    elif(TNumber==101):
        value7tf=value7+TSum;value9tf=value9-TSum;Transfer='7<-9'
    elif(TNumber==102):
        value7tf=value7+TSum;value10tf=value10-TSum;Transfer='7<-10'   
    elif(TNumber==103):
        value7tf=value7+TSum;value11tf=value11-TSum;Transfer='7<-11'
    elif(TNumber==104):
        value7tf=value7+TSum;value12tf=value12-TSum;Transfer='7<-12' 
    elif(TNumber==105):
        value7tf=value7+TSum;value13tf=value13-TSum;Transfer='7<-13'  
    elif(TNumber==106):
        value7tf=value7+TSum;value14tf=value14-TSum;Transfer='7<-14' 
    elif(TNumber==107):
        value7tf=value7+TSum;value15tf=value15-TSum;Transfer='7<-15'
    elif(TNumber==108):
        value7tf=value7+TSum;value16tf=value16-TSum;Transfer='7<-16'
    elif(TNumber==109):
        value7tf=value7+TSum;value17tf=value17-TSum;Transfer='7<-17' 
    elif(TNumber==110):
        value7tf=value7+TSum;value18tf=value18-TSum;Transfer='7<-18'   
    elif(TNumber==111):
        value7tf=value7+TSum;value19tf=value19-TSum;Transfer='7<-19'  
    elif(TNumber==112):
        value7tf=value7+TSum;value20tf=value20-TSum;Transfer='7<-20'  
    
    elif(TNumber==113):
        value8tf=value8+TSum;value9tf=value9-TSum;Transfer='8<-9'
    elif(TNumber==114):
        value8tf=value8+TSum;value10tf=value10-TSum;Transfer='8<-10'
    elif(TNumber==115):
        value8tf=value8+TSum;value11tf=value11-TSum;Transfer='8<-11'
    elif(TNumber==116):
        value8tf=value8+TSum;value12tf=value12-TSum;Transfer='8<-12' 
    elif(TNumber==117):
        value8tf=value8+TSum;value13tf=value13-TSum;Transfer='8<-13'   
    elif(TNumber==118):
        value8tf=value8+TSum;value14tf=value14-TSum;Transfer='8<-14'   
    elif(TNumber==119):
        value8tf=value8+TSum;value15tf=value15-TSum;Transfer='8<-15'
    elif(TNumber==120):
        value8tf=value8+TSum;value16tf=value16-TSum;Transfer='8<-16'
    elif(TNumber==121):
        value8tf=value8+TSum;value17tf=value17-TSum;Transfer='8<-17'  
    elif(TNumber==122):
        value8tf=value8+TSum;value18tf=value18-TSum;Transfer='8<-18' 
    elif(TNumber==123):
        value8tf=value8+TSum;value19tf=value19-TSum;Transfer='8<-19'
    elif(TNumber==124):
        value8tf=value8+TSum;value20tf=value20-TSum;Transfer='8<-20' 
       
    elif(TNumber==125):
        value9tf=value9+TSum;value10tf=value10-TSum;Transfer='9<-10'
    elif(TNumber==126):
        value9tf=value9+TSum;value11tf=value11-TSum;Transfer='9<-11'
    elif(TNumber==127):
        value9tf=value9+TSum;value12tf=value12-TSum;Transfer='9<-12' 
    elif(TNumber==128):
        value9tf=value9+TSum;value13tf=value13-TSum;Transfer='9<-13'  
    elif(TNumber==129):
        value9tf=value9+TSum;value14tf=value14-TSum;Transfer='9<-14'
    elif(TNumber==130):
        value9tf=value9+TSum;value15tf=value15-TSum;Transfer='9<-15'
    elif(TNumber==131):
        value9tf=value9+TSum;value16tf=value16-TSum;Transfer='9<-16'
    elif(TNumber==132):
        value9tf=value9+TSum;value17tf=value17-TSum;Transfer='9<-17' 
    elif(TNumber==133):
        value9tf=value9+TSum;value18tf=value18-TSum;Transfer='9<-18'   
    elif(TNumber==134):
        value9tf=value9+TSum;value19tf=value19-TSum;Transfer='9<-19' 
    elif(TNumber==135):
        value9tf=value9+TSum;value20tf=value20-TSum;Transfer='9<-20'    
       
    elif(TNumber==136):
        value10tf=value10+TSum;value11tf=value11-TSum;Transfer='10<-11' 
    elif(TNumber==137):
        value10tf=value10+TSum;value12tf=value12-TSum;Transfer='10<-12' 
    elif(TNumber==138):
        value10tf=value10+TSum;value13tf=value13-TSum;Transfer='10<-13' 
    elif(TNumber==139):
        value10tf=value10+TSum;value14tf=value14-TSum;Transfer='10<-14'
    elif(TNumber==140):
        value10tf=value10+TSum;value15tf=value15-TSum;Transfer='10<-15'
    elif(TNumber==141):
        value10tf=value10+TSum;value16tf=value16-TSum;Transfer='10<-16' 
    elif(TNumber==142):
        value10tf=value10+TSum;value17tf=value17-TSum;Transfer='10<-17' 
    elif(TNumber==143):
        value10tf=value10+TSum;value18tf=value18-TSum;Transfer='10<-18' 
    elif(TNumber==144):
        value10tf=value10+TSum;value19tf=value19-TSum;Transfer='10<-19'  
    elif(TNumber==145):
        value10tf=value10+TSum;value20tf=value20-TSum;Transfer='10<-20' 
    
    elif(TNumber==146):
        value11tf=value11+TSum;value12tf=value12-TSum;Transfer='11<-12' 
    elif(TNumber==147):
        value11tf=value11+TSum;value13tf=value13-TSum;Transfer='11<-13'    
    elif(TNumber==148):
        value11tf=value11+TSum;value14tf=value14-TSum;Transfer='11<-14'
    elif(TNumber==149):
        value11tf=value11+TSum;value15tf=value15-TSum;Transfer='11<-15'
    elif(TNumber==150):
        value11tf=value11+TSum;value16tf=value16-TSum;Transfer='11<-16'
    elif(TNumber==151):
        value11tf=value11+TSum;value17tf=value17-TSum;Transfer='11<-17'
    elif(TNumber==152):
        value11tf=value11+TSum;value18tf=value18-TSum;Transfer='11<-18' 
    elif(TNumber==153):
        value11tf=value11+TSum;value19tf=value19-TSum;Transfer='11<-19' 
    elif(TNumber==154):
        value11tf=value11+TSum;value20tf=value20-TSum;Transfer='11<-20' 
    
    elif(TNumber==155):
        value12tf=value12+TSum;value13tf=value13-TSum;Transfer='12<-13'    
    elif(TNumber==156):
        value12tf=value12+TSum;value14tf=value14-TSum;Transfer='12<-14'  
    elif(TNumber==157):
        value12tf=value12+TSum;value15tf=value15-TSum;Transfer='12<-15'
    elif(TNumber==158):
        value12tf=value12+TSum;value16tf=value16-TSum;Transfer='12<-16'
    elif(TNumber==159):
        value12tf=value12+TSum;value17tf=value17-TSum;Transfer='12<-17'  
    elif(TNumber==160):
        value12tf=value12+TSum;value18tf=value18-TSum;Transfer='12<-18'
    elif(TNumber==161):
        value12tf=value12+TSum;value19tf=value19-TSum;Transfer='12<-19'
    elif(TNumber==162):
        value12tf=value12+TSum;value20tf=value20-TSum;Transfer='12<-20'             
       
    elif(TNumber==163):
        value13tf=value13+TSum;value14tf=value14-TSum;Transfer='13<-14' 
    elif(TNumber==164):
        value13tf=value13+TSum;value15tf=value15-TSum;Transfer='13<-15'
    elif(TNumber==165):
        value13tf=value13+TSum;value16tf=value16-TSum;Transfer='13<-16'  
    elif(TNumber==166):
        value13tf=value13+TSum;value17tf=value17-TSum;Transfer='13<-17'   
    elif(TNumber==167):
        value13tf=value13+TSum;value18tf=value18-TSum;Transfer='13<-18'     
    elif(TNumber==168):
        value13tf=value13+TSum;value19tf=value19-TSum;Transfer='13<-19' 
    elif(TNumber==169):
        value13tf=value13+TSum;value20tf=value20-TSum;Transfer='13<-20' 
      
    elif(TNumber==170):
        value14tf=value14+TSum;value15tf=value15-TSum;Transfer='14<-15'
    elif(TNumber==171):
        value14tf=value14+TSum;value16tf=value16-TSum;Transfer='14<-16'
    elif(TNumber==172):
        value14tf=value14+TSum;value17tf=value17-TSum;Transfer='14<-17' 
    elif(TNumber==173):
        value14tf=value14+TSum;value18tf=value18-TSum;Transfer='14<-18' 
    elif(TNumber==174):
        value14tf=value14+TSum;value19tf=value19-TSum;Transfer='14<-19' 
    elif(TNumber==175):
        value14tf=value14+TSum;value20tf=value20-TSum;Transfer='14<-20' 
        
    elif(TNumber==176):
        value15tf=value15+TSum;value16tf=value16-TSum;Transfer='15<-16' 
    elif(TNumber==177):
        value15tf=value15+TSum;value17tf=value17-TSum;Transfer='15<-17' 
    elif(TNumber==178):
        value15tf=value15+TSum;value18tf=value18-TSum;Transfer='15<-18'  
    elif(TNumber==179):
        value15tf=value15+TSum;value19tf=value19-TSum;Transfer='15<-19'  
    elif(TNumber==180):
        value15tf=value15+TSum;value20tf=value20-TSum;Transfer='15<-20'
   
    elif(TNumber==181):
        value16tf=value16+TSum;value17tf=value17-TSum;Transfer='16<-17'
    elif(TNumber==182):
        value16tf=value16+TSum;value18tf=value18-TSum;Transfer='16<-18'  
    elif(TNumber==183):
        value16tf=value16+TSum;value19tf=value19-TSum;Transfer='16<-19'  
    elif(TNumber==184):
        value16tf=value16+TSum;value20tf=value20-TSum;Transfer='16<-20' 
  
    elif(TNumber==185):
        value17tf=value17+TSum;value18tf=value18-TSum;Transfer='17<-18' 
    elif(TNumber==186):
        value17tf=value17+TSum;value19tf=value19-TSum;Transfer='17<-19' 
    elif(TNumber==187):
        value17tf=value17+TSum;value20tf=value20-TSum;Transfer='17<-20'
    
    elif(TNumber==188):
        value18tf=value18+TSum;value19tf=value19-TSum;Transfer='18<-19'
    elif(TNumber==189):
        value18tf=value18+TSum;value20tf=value20-TSum;Transfer='18<-20'
   
    elif(TNumber==190):
        value19tf=value19+TSum;value20tf=value20-TSum;Transfer='19<-20'   
    ##############################################################################
    vlisttf =[value1tf,value2tf,value3tf,value4tf,value5tf,value6tf,value7tf,
              value8tf,value9tf,value10tf,value11tf,value12tf,value13tf,value14tf,
              value15tf,value16tf,value17tf,value18tf,value19tf,value20tf]
    vlisttf.sort()
    
    value1tf=vlisttf[0];value2tf=vlisttf[1];value3tf=vlisttf[2];value4tf=vlisttf[3]
    value5tf=vlisttf[4];value6tf=vlisttf[5];value7tf=vlisttf[6];value8tf=vlisttf[7]
    value9tf=vlisttf[8];value10tf=vlisttf[9];value11tf=vlisttf[10];value12tf=vlisttf[11]
    value13tf=vlisttf[12];value14tf=vlisttf[13];value15tf=vlisttf[14];value16tf=vlisttf[15]
    value17tf=vlisttf[16];value18tf=vlisttf[17];value19tf=vlisttf[18];value20tf=vlisttf[19]
    
    g1=value1/summ;g2=value2/summ;g3=value3/summ;g4=value4/summ;g5=value5/summ
    g6=value6/summ;g7=value7/summ;g8=value8/summ;g9=value9/summ;g10=value10/summ
    g11=value11/summ;g12=value12/summ;g13=value13/summ;g14=value14/summ;g15=value15/summ
    g16=value16/summ;g17=value17/summ;g18=value18/summ;g19=value19/summ;g20=value20/summ       
    
    g1tf=value1tf/summ;g2tf=value2tf/summ;g3tf=value3tf/summ;g4tf=value4tf/summ
    g5tf=value5tf/summ;g6tf=value6tf/summ;g7tf=value7tf/summ;g8tf=value8tf/summ
    g9tf=value9tf/summ;g10tf=value10tf/summ;g11tf=value11tf/summ;g12tf=value12tf/summ
    g13tf=value13tf/summ;g14tf=value14tf/summ;g15tf=value15tf/summ;g16tf=value16tf/summ
    g17tf=value17tf/summ;g18tf=value18tf/summ;g19tf=value19tf/summ;g20tf=value20tf/summ      

    #Income shares
    percent1=g1*100;percent2=g2*100;percent3=g3*100;percent4=g4*100;percent5=g5*100
    percent6=g6*100;percent7=g7*100;percent8=g8*100;percent9=g9*100;percent10=g10*100
    percent11=g11*100;percent12=g12*100;percent13=g13*100;percent14=g14*100
    percent15=g15*100;percent16=g16*100;percent17=g17*100;percent18=g18*100
    percent19=g19*100;percent20=g20*100         
    
    percent1tf=g1tf*100;percent2tf=g2tf*100;percent3tf=g3tf*100;percent4tf=g4tf*100
    percent5tf=g5tf*100;percent6tf=g6tf*100;percent7tf=g7tf*100;percent8tf=g8tf*100
    percent9tf=g9tf*100;percent10tf=g10tf*100;percent11tf=g11tf*100;percent12tf=g12tf*100
    percent13tf=g13tf*100;percent14tf=g14tf*100;percent15tf=g15tf*100;percent16tf=g16tf*100
    percent17tf=g17tf*100;percent18tf=g18tf*100;percent19tf=g19tf*100;percent20tf=g20tf*100        
    
    #Cummulative income shares
    q1=percent1;q2=q1+percent2;q3=q2+percent3;q4=q3+percent4;q5=q4+percent5;q6=q5+percent6
    q7=q6+percent7;q8=q7+percent8;q9=q8+percent9;q10=q9+percent10;q11=q10+percent11
    q12=q11+percent12;q13=q12+percent13;q14=q13+percent14;q15=q14+percent15;q16=q15+percent16
    q17=q16+percent17;q18=q17+percent18;q19=q18+percent19;q20=q19+percent20         
    
    q1tf=percent1tf;q2tf=q1tf+percent2tf;q3tf=q2tf+percent3tf;q4tf=q3tf+percent4tf
    q5tf=q4tf+percent5tf;q6tf=q5tf+percent6tf;q7tf=q6tf+percent7tf;q8tf=q7tf+percent8tf
    q9tf=q8tf+percent9tf;q10tf=q9tf+percent10tf;q11tf=q10tf+percent11tf;q12tf=q11tf+percent12tf
    q13tf=q12tf+percent13tf;q14tf=q13tf+percent14tf;q15tf=q14tf+percent15tf;q16tf=q15tf+percent16tf
    q17tf=q16tf+percent17tf;q18tf=q17tf+percent18tf;q19tf=q18tf+percent19tf;q20tf=q19tf+percent20tf         

    ###############################################################################################
    #Gini coefficient 
    proportion1=1/n*100;proportion2=2/n*100;proportion3=3/n*100;proportion4=4/n*100
    proportion5=5/n*100;proportion6=6/n*100;proportion7=7/n*100;proportion8=8/n*100
    proportion9=9/n*100;proportion10=10/n*100;proportion11=11/n*100;proportion12=12/n*100
    proportion13=13/n*100;proportion14=14/n*100;proportion15=15/n*100;proportion16=16/n*100
    proportion17=17/n*100;proportion18=18/n*100;proportion19=19/n*100
             
    sumProportions=950 #100/n * (n*n-1)/2
    
    #n-1 distances between Lorenz curve and 45-degree line
    distance1=abs(proportion1-q1);distance2=abs(proportion2-q2)
    distance3=abs(proportion3-q3);distance4=abs(proportion4-q4)
    distance5=abs(proportion5-q5);distance6=abs(proportion6-q6)
    distance7=abs(proportion7-q7);distance8=abs(proportion8-q8)
    distance9=abs(proportion9-q9);distance10=abs(proportion10-q10)
    distance11=abs(proportion11-q11);distance12=abs(proportion12-q12)
    distance13=abs(proportion13-q13);distance14=abs(proportion14-q14)
    distance15=abs(proportion15-q15);distance16=abs(proportion16-q16)
    distance17=abs(proportion17-q17);distance18=abs(proportion18-q18)
    distance19=abs(proportion19-q19)        
   
    sumdistances=(distance1+distance2+distance3+distance4+distance5+distance6+distance7+
                  distance8+distance9+distance10+distance11+distance12+distance13+distance14+
                  distance15+distance16+distance17+distance18+distance19)

    Gini=(sumdistances/sumProportions)*((n-1)/n)
    ###############################################################################################
    #Gini coefficient after a progressive transfer
    distance1tf=abs(proportion1-q1tf);distance2tf=abs(proportion2-q2tf)
    distance3tf=abs(proportion3-q3tf);distance4tf=abs(proportion4-q4tf)
    distance5tf=abs(proportion5-q5tf);distance6tf=abs(proportion6-q6tf)
    distance7tf=abs(proportion7-q7tf);distance8tf=abs(proportion8-q8tf)
    distance9tf=abs(proportion9-q9tf);distance10tf=abs(proportion10-q10tf)
    distance11tf=abs(proportion11-q11tf);distance12tf=abs(proportion12-q12tf)
    distance13tf=abs(proportion13-q13tf);distance14tf=abs(proportion14-q14tf)
    distance15tf=abs(proportion15-q15tf);distance16tf=abs(proportion16-q16tf)
    distance17tf=abs(proportion17-q17tf);distance18tf=abs(proportion18-q18tf)
    distance19tf=abs(proportion19-q19tf)
    
    sumdistancestf=(distance1tf+distance2tf+distance3tf+distance4tf+distance5tf+
                    distance6tf+distance7tf+distance8tf+distance9tf+distance10tf+
                    distance11tf+distance12tf+distance13tf+distance14tf+distance15tf+
                    distance16tf+distance17tf+distance18tf+distance19tf)
    
    Ginitf=(sumdistancestf/sumProportions)*((n-1)/n)
    Ginid=100-((100/Gini)*Ginitf)
    if(Ginid<0):
         continue
    ###############################################################################################
    #GR: sensitive to right-skewed distributions
    rdistance1=distance1*rweight1;rdistance2=distance2*rweight2
    rdistance3=distance3*rweight3;rdistance4=distance4*rweight4
    rdistance5=distance5*rweight5;rdistance6=distance6*rweight6
    rdistance7=distance7*rweight7;rdistance8=distance8*rweight8
    rdistance9=distance9*rweight9;rdistance10=distance10*rweight10
    rdistance11=distance11*rweight11;rdistance12=distance12*rweight12
    rdistance13=distance13*rweight13;rdistance14=distance14*rweight14
    rdistance15=distance15*rweight15;rdistance16=distance16*rweight16
    rdistance17=distance17*rweight17;rdistance18=distance18*rweight18
    rdistance19=distance19*rweight19
   
    sumrdistances=(rdistance1+rdistance2+rdistance3+rdistance4+rdistance5+rdistance6+rdistance7+
                   rdistance8+rdistance9+rdistance10+rdistance11+rdistance12+rdistance13+
                   rdistance14+rdistance15+rdistance16+rdistance17+rdistance18+rdistance19)
    
    GR=(sumrdistances/sumProportions)*((n-1)/n)
    ###############################################################################################
    #GR after transfer
    rdistance1tf=distance1tf*rweight1;rdistance2tf=distance2tf*rweight2
    rdistance3tf=distance3tf*rweight3;rdistance4tf=distance4tf*rweight4
    rdistance5tf=distance5tf*rweight5;rdistance6tf=distance6tf*rweight6
    rdistance7tf=distance7tf*rweight7;rdistance8tf=distance8tf*rweight8
    rdistance9tf=distance9tf*rweight9;rdistance10tf=distance10tf*rweight10
    rdistance11tf=distance11tf*rweight11;rdistance12tf=distance12tf*rweight12
    rdistance13tf=distance13tf*rweight13;rdistance14tf=distance14tf*rweight14
    rdistance15tf=distance15tf*rweight15;rdistance16tf=distance16tf*rweight16
    rdistance17tf=distance17tf*rweight17;rdistance18tf=distance18tf*rweight18
    rdistance19tf=distance19tf*rweight19
    
    sumrdistancestf=(rdistance1tf+rdistance2tf+rdistance3tf+rdistance4tf+rdistance5tf+
                     rdistance6tf+rdistance7tf+rdistance8tf+rdistance9tf+rdistance10tf+
                     rdistance11tf+rdistance12tf+rdistance13tf+rdistance14tf+rdistance15tf+
                     rdistance16tf+rdistance17tf+rdistance18tf+rdistance19tf)
    
    GRtf=(sumrdistancestf/sumProportions)*((n-1)/n)
    GRd=100-((100/GR)*GRtf)
    ###################################################################################
    #GL: sensitive to left-skewed distributions
    ldistance1=distance1*lweight1;ldistance2=distance2*lweight2;ldistance3=distance3*lweight3
    ldistance4=distance4*lweight4;ldistance5=distance5*lweight5;ldistance6=distance6*lweight6
    ldistance7=distance7*lweight7;ldistance8=distance8*lweight8;ldistance9=distance9*lweight9
    ldistance10=distance10*lweight10;ldistance11=distance11*lweight11
    ldistance12=distance12*lweight12;ldistance13=distance13*lweight13
    ldistance14=distance14*lweight14;ldistance15=distance15*lweight15
    ldistance16=distance16*lweight16;ldistance17=distance17*lweight17
    ldistance18=distance18*lweight18;ldistance19=distance19*lweight19
    
    sumldistances=(ldistance1+ldistance2+ldistance3+ldistance4+ldistance5+ldistance6+ldistance7+
                   ldistance8+ldistance9+ldistance10+ldistance11+ldistance12+ldistance13+
                   ldistance14+ldistance15+ldistance16+ldistance17+ldistance18+ldistance19)
    
    GL=(sumldistances/sumProportions)*((n-1)/n)
    ###############################################################################################
    #GL after transfer
    ldistance1tf=distance1tf*lweight1;ldistance2tf=distance2tf*lweight2
    ldistance3tf=distance3tf*lweight3;ldistance4tf=distance4tf*lweight4
    ldistance5tf=distance5tf*lweight5;ldistance6tf=distance6tf*lweight6
    ldistance7tf=distance7tf*lweight7;ldistance8tf=distance8tf*lweight8
    ldistance9tf=distance9tf*lweight9;ldistance10tf=distance10tf*lweight10
    ldistance11tf=distance11tf*lweight11;ldistance12tf=distance12tf*lweight12
    ldistance13tf=distance13tf*lweight13;ldistance14tf=distance14tf*lweight14
    ldistance15tf=distance15tf*lweight15;ldistance16tf=distance16tf*lweight16
    ldistance17tf=distance17tf*lweight17;ldistance18tf=distance18tf*lweight18
    ldistance19tf=distance19tf*lweight19
   
    sumldistancestf=(ldistance1tf+ldistance2tf+ldistance3tf+ldistance4tf+ldistance5tf+
                     ldistance6tf+ldistance7tf+ldistance8tf+ldistance9tf+ldistance10tf+
                     ldistance11tf+ldistance12tf+ldistance13tf+ldistance14tf+ldistance15tf+
                     ldistance16tf+ldistance17tf+ldistance18tf+ldistance19tf)
    
    GLtf=(sumldistancestf/sumProportions)*((n-1)/n)
    GLd=100-((100/GL)*GLtf)
    ################################################################################
    SAG=Gini+(abs(GR-GL)/2)
    SAGtf=Ginitf+(abs(GRtf-GLtf)/2)
    SAGd=100-((100/SAG)*SAGtf)
    ################################################################################
    Skew=scipy.stats.skew(vlist, axis=0, bias=False)
    #################################################################################
    i+=1
    dataframe.loc[len(dataframe)] = (TNumber,Transfer,TSum,SAG,SAGtf,SAGd,
                                     GR,GRtf,GRd,GL,GLtf,GLd,Gini,Ginitf,Ginid,
                                     Skew,mean,median,
                                     percent1,percent2,percent3,percent4,percent5,
                                     percent6,percent7,percent8,percent9,percent10,
                                     percent11,percent12,percent13,percent14,percent15,
                                     percent16,percent17,percent18,percent19,percent20,
                                     percent1tf,percent2tf,percent3tf,percent4tf,percent5tf,
                                     percent6tf,percent7tf,percent8tf,percent9tf,percent10tf,
                                     percent11tf,percent12tf,percent13tf,percent14tf,percent15tf,
                                     percent16tf,percent17tf,percent18tf,percent19tf,percent20tf,
                                     value1,value2,value3,value4,value5,
                                     value6,value7,value8,value9,value10,
                                     value11,value12,value13,value14,value15,
                                     value16,value17,value18,value19,value20,
                                     value1tf,value2tf,value3tf,value4tf,value5tf,
                                     value6tf,value7tf,value8tf,value9tf,value10tf,
                                     value11tf,value12tf,value13tf,value14tf,value15tf,
                                     value16tf,value17tf,value18tf,value19tf,value20tf           
                                    )

# %%
dataframe
# Out:
#       TNumber Transfer  TSum       SAG     SAGtf      SAGd        GR  \
# 0          84    5<-19  0.40  0.319973  0.319728  0.076298  0.319973
# 1          29    2<-12  0.45  0.313155  0.312984  0.054325  0.288610
# 2          46    3<-12  0.49  0.288662  0.288468  0.067210  0.288225
# 3         183   16<-19  0.30  0.316465  0.316430  0.010921  0.316465
# 4         140   10<-15  0.40  0.274653  0.274566  0.031892  0.274653
# ...       ...      ...   ...       ...       ...       ...       ...
# 9996      120    8<-16  0.10  0.309921  0.309899  0.006833  0.285626
# 9997       76    5<-11  0.30  0.344680  0.344623  0.016702  0.344680
# 9998      147   11<-13  0.30  0.291592  0.291576  0.005375  0.276140
# 9999       54    3<-20  0.20  0.448153  0.448001  0.033952  0.448153
# 10000     159   12<-17  0.20  0.389021  0.388962  0.014995  0.389021
#
#            GRtf       GRd        GL  ...  value11tf  value12tf  value13tf  \
# ...
